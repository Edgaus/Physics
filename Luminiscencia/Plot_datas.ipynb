# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
hoja1 = pd.read_excel('Hoja1.xlsx', skiprows=5)
hoja1['señal'] = hoja1['0703024U1- muestra']- 	hoja1['0703024U1- ruido']
hoja1.plot(x='Wavelength[nm]', y='señal')
# Out:
# <AxesSubplot: xlabel='Wavelength[nm]'>

# %%
hoja3 = pd.read_excel('Hoja3.xlsx', skiprows=5)
hoja3['señal'] = hoja3['0703024U1- muestra']- 	hoja3['0703024U1- ruido']
hoja3.plot(x='Wavelength[nm]', y='señal')
# Out:
# <AxesSubplot: xlabel='Wavelength[nm]'>

# %%
hoja4 = pd.read_excel('Hoja4.xlsx', skiprows=5)
hoja4['señal'] = hoja4['0703024U1- muestra']- 	hoja4['0703024U1- ruido']
hoja4.plot(x='Wavelength[nm]', y='señal')
# Out:
# <AxesSubplot: xlabel='Wavelength[nm]'>

# %%
hoja5 = pd.read_excel('Hoja5.xlsx', skiprows=5)
hoja5['señal'] = hoja5['0703024U1- m210']- 	hoja5['0703024U1- ruido']
hoja5.plot(x='Wavelength[nm]', y='señal')
# Out:
# <AxesSubplot: xlabel='Wavelength[nm]'>

# %%
m_207 = pd.read_excel('Hoja1.xlsx', skiprows=5)
m_208 = pd.read_excel('Hoja3.xlsx', skiprows=5)
m_209 = pd.read_excel('Hoja7.xlsx', skiprows=5)
m_210 = pd.read_excel('Hoja6.xlsx', skiprows=5)



señal = m_209.copy().drop(['0703024U1- Muestra209', '0703024U1- ruido' ], axis=1)
señal['850 ºC'] = m_209['0703024U1- Muestra209']-m_209['0703024U1- ruido']
señal['860 ºC'] =  m_210['0703024U1- muestra']-m_210['0703024U1- ruido']
señal['840 ºC'] =  m_207['0703024U1- muestra']-m_207['0703024U1- ruido']
señal['830 ºC'] =  m_208['0703024U1- muestra']-m_208['0703024U1- ruido']



señal.plot(x='Wavelength[nm]', y=['830 ºC','840 ºC','850 ºC','860 ºC'], title='Luminicence of AlN films', ylabel='Counts' )
# Out:
# <AxesSubplot: title={'center': 'Luminicence of AlN films'}, xlabel='Wavelength[nm]', ylabel='Counts'>

# %%
m_210 = pd.read_excel('Hoja6.xlsx', skiprows=5)
m_210['señal'] = m_210['0703024U1- muestra']-m_210['0703024U1- ruido']
m_210.plot( x='Wavelength[nm]', y='señal' )
# Out:
# <AxesSubplot: xlabel='Wavelength[nm]'>
